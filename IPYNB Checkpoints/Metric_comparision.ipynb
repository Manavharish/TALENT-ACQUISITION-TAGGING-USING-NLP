# %% [markdown]
# # Metrics comparision

# %%
# Import Module
import os
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer #pip install sklearn
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer #pip install sentence-transformers

# Folder path
path = "/Users/snigdharao/Desktop/project"
model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
def series_to_list(series):
    list =[]
    for s in series:
        s = re.sub("[\(\[]", "", str(s))
        s = re.sub("[\)\]]", "", str(s))
        s = re.sub("'", "", str(s))
        list = [k for k in s.split(",")]
    return list

# %%
def cv_score_calculator(token, sublist):
    sub_text = " ".join(sublist)
    res_text = " ".join(token)
    sentences = [sub_text,res_text]
    vectorizer = CountVectorizer()
    matrix = vectorizer.fit_transform(sentences)
    score = cosine_similarity(matrix)[0][1]*100
    return round(score,2)

# %%
def tf_idf_score_calculator(token, sublist):
    sub_text = " ".join(sublist)
    res_text = " ".join(token)
    sentences = [sub_text,res_text]
    vectorizer = TfidfVectorizer()
    matrix = vectorizer.fit_transform(sentences)
    score = cosine_similarity(matrix)[0][1] * 100
    return round(score, 2)

# %%
def bert_score_calculator(token, sublist):
    sub_text = " ".join(sublist)
    res_text = " ".join(token)
    sentences = [sub_text,res_text]
    sentence_embeddings = model.encode(sentences)
    score = cosine_similarity([sentence_embeddings[0]],sentence_embeddings[1:])
    return round(score[0][0]*100,2)

# %%
def resume_selector():
    # Change the directory

    resume_list = pd.read_csv('Resume_list.csv')
    job_descript = pd.read_csv('Sublist.csv')
    candidate_data= pd.DataFrame(resume_list["File name"].tolist(),columns=['candidate_name'])
    job_list =[]
    
    job_role =job_descript.loc[[0]]['JobRole'].to_string()
    job_role = job_role.split("   ")[1]
    job_list.append(job_role)

    print(f"+++++ Processing Resumes for Job role {job_role} +++++")
    sublist = series_to_list(job_descript.loc[[0]]['Sublist'])
    cv_score=[]
    tf_idf_score=[]
    bert_score=[]

    for j in range(len(resume_list)):
        print(resume_list.loc[[j]]["File name"].to_string())
        token_list = series_to_list(resume_list.loc[[j]]["Token_list"])
        # CountVectorizer
        score = cv_score_calculator(token_list,sublist)
        cv_score.append(score)

        score = tf_idf_score_calculator(token_list, sublist)
        tf_idf_score.append(score)

        score = bert_score_calculator(token_list, sublist)
        bert_score.append(score)

    cv_score_df = pd.DataFrame(cv_score, columns=['cv_score'])
    tf_idf_score_df = pd.DataFrame(tf_idf_score, columns=['tf_idf_score'])
    bert_score_df = pd.DataFrame(bert_score, columns=['bert_score'])
    candidate_data = pd.concat([candidate_data,cv_score_df,tf_idf_score_df,bert_score_df],axis=1)
    candidate_data.index = candidate_data['candidate_name']
    candidate_data = candidate_data.iloc[:, 1:]
    print(candidate_data)
    candidate_data.to_csv('MetricScore.csv')

# %%
resume_selector()
# Out:
# +++++ Processing Resumes for Job role  Business_analyst +++++
# 0    Abiral_Pandey_Fullstack_Java.docx
# 1    Achyuth Resume_8.docx
# 2    Adelina_Erimia_PMP1.docx
# 3    Adhi Gopalam - SM.docx
# 4    AjayKumar.docx
# 5    Akhil.profile.docx
# 6    Alekhya Resume.docx
# 7    Amar Sr BSA.docx
# 8    Ami Jape.docx
# 9    Amrinder Business Analyst.docx
# 10    Amulya Komatineni.docx
# 11    Anil Krishna Mogalaturthi.docx
# 12    AnilAgarwal.docx
# 13    Anudeep N_Sr Java Developer.docx
# 14    Ashok Jayakumar - PM.docx
# 15    Ashwini J2EE Developer.docx
# 16    Atul_Mathur_Resume.docx
# 17    Avathika BA-Healthcare_.docx
# 18    avinash G.docx
# 19    B Shaker-Sr BSA-Scrum Master .docx
# 20    B Suresh Kumar_Project Manager_1.docx
# 21    BA - Abhishek.docx
# 22    BA - Navneet.docx
# 23    BA Kiran.docx
# 24    BA with INV.docx
# 25    Balaji Gopalakrishnan Project Manager.docx
# 26    Balakrishna Sudabathula.docx
# 27    Bapuji Hadoop developer.docx
# 28    Bharat Arora_CV_PMP _ ERP1.docx
# 29    Bharatha BA Resume.docx
# 30    Brahma-Resume (BA).docx
# 31    Business Analyst_GHyma.docx
# 32    Chandler_BA.docx
# 33    chenna kesava.docx
# 34    CHETAN_Sr Java Developer.docx
# 35    Dantu Padmasri - Project Manager.docx
# 36    Dave.docx
# 37    Deepika Chintalapati.docx
# 38    Derik.docx
# 39    Dhanalaxmi -BA.docx
# 40    Drakshajavauidev.docx
# 41    Francis Gomes Resume.docx
# 42    Gautami Bulusu Mobile Testing 3.docx
# 43    Gokul Selvam S PM.docx
# 44    Gopi.docx
# 45    Gururaja Murthy PMCPCSM.docx
# 46    Haarika_BA.docx
# 47    Harika_java.docx
# 48    Harish K.docx
# 49    harish S.docx
# 50    HARI_Sr.Java Developer.docx
# 51    Harshitha Challa.docx
# 52    indrakaran soma.docx
# 53    jagadeesh k.docx
# 54    Jagan S Iyer PM.docx
# 55    Jaya prakash.docx
# 56    Jayadattaperi N.docx
# 57    jeck P.docx
# 58    Jennifer  M. Conte.docx
# 59    Jimi_Desai_PM.docx
# 60    kalyan das.docx
# 61    Kashyap K. Vora resume.docx
# 62    KIRAN KUMAR.docx
# 63    komal patel.docx
# 64    Komala BSA Resume.docx
# 65    Krishna Kuruvella.docx
# 66    Krishna Sr. BSA Resume.docx
# 67    Krishnapriya_BA.docx
# 68    Krishna_BSA.docx
# 69    Krishna_SrJava.docx
# 70    Kumar Raj.docx
# 71    Kuppurajbabu_BA.docx
# 72    KY BA PM UPDATED RESUME .docx
# 73    Madhuri Pawar.docx
# 74    madhuri R.docx
# 75    madhuri_java.docx
# 76    mahesh_Java.docx
# 77    Mahesh_Kamath_PM (1).docx
# 78    Manikanta P.docx
# 79    manish_singh_resume.docx
# 80    Mani_Hadoop.docx
# 81    Manohar B.docx
# 82    Manohar Reddy.docx
# 83    manohar.B.docx
# 84    Mehul.docx
# 85    Mitali Barman_Resume.docx
# 86    Mohamad Jamil.docx
# 87    Mohammad Resume.docx
# 88    mohid_rj.docx
# 89    mounika BA resume 7.docx
# 90    Mounika health care resume.docx
# 91    MounikaReddy.docx
# 92    Mounika_P.docx
# 93    Nandini_Resume.docx
# 94    Naren Sr.BA .docx
# 95    Naresh V.docx
# 96    Naveen Arora.docx
# 97    Naveen Kumar Bandela.docx
# 98    Naveen.S_Resume.docx
# 99    Navneeth Resume.docx
# 100    Neha Mugghala.docx
# 101    Nikhil.docx
# 102    Nikith Reddy.docx
# 103    Nikki_Nimmagadd.docx
# 104    Nilesh-resume_1_phplead.docx
# 105    Niteesh Java Developer.docx
# 106    nithin katapally.docx
# 107    nithin Reddy.docx
# 108    Othman - Project Manager.docx
# 109    Pankaj BSA.docx
# 110    ParthMPatel_BA.docx
# 111    Pavan Kumar Full Stack Java Developer.docx
# 112    Pavan Sr Business Analyst resume.docx
# 113    Pierre John.docx
# 114    PM RESUME.docx
# 115    Pranay P.docx
# 116    Prashant Chawda_resume.docx
# 117    Praveen B.docx
# 118    Praveen T.docx
# 119    Priya B.docx
# 120    Priyanka Sr BSA Resume.docx
# 121    Priya_Sharma.docx
# 122    Rajendra-PMP-CSM.docx
# 123    Rajesh_k.docx
# 124    ram krishna.docx
# 125    ram nandyala.docx
# 126    Ramachandra EDA.docx
# 127    Ramteja Motupalli.docx
# 128    RAMYA BUSINESS ANALYST RESUME.docx
# 129    Randy Adams.docx
# 130    Ranjan_Project Manager-Scrum Master.docx
# 131    Rao_Java.docx
# 132    Rashmitha R.docx
# 133    Ravi Pattar- Sr. Agile Program manager.docx
# 134    Ravi Reddy.docx
# 135    RaviBurra_Certified PM_DevOps.docx
# 136    ravikiran JALASUTRAPU.docx
# 137    RaviRaju_Resume.docx
# 138    Reddemma_Lankipalle.docx
# 139    Resume - Kishore Kotapati - 218E - BA.docx
# 140    Resume - PM Agile-Scrum.docx
# 141    Resume2018March.docx
# 142    Resume_Spoorti Pandit_BSA.docx
# 143    Robinson.docx
# 144    Rohanu Resume.docx
# 145    ronith s.docx
# 146    Sahas BA Resume.docx
# 147    Sahithi K.docx
# 148    sai k.docx
# 149    Sai Krishna BA.docx
# 150    Sai kumar.docx
# 151    Sai Srinivas_Sr_Java_Developer.docx
# 152    sairithvik alla.docx
# 153    Saiteja G.docx
# 154    Samir Naik-NJ - Feb 2018-V6.0.docx
# 155    sanjay kumar.docx
# 156    Santosh Arugula BA.docx
# 157    Sarath M.docx
# 158    SaravanaKumar.docx
# 159    Satish Reddy.docx
# 160    Satish Uduta.docx
# 161    Shail_Tank-Business Analyst .docx
# 162    Shaker Resume.docx
# 163    Sharath Java.docx
# 164    Shashank.docx
# 165    Shelly Woods.docx
# 166    Shiuli Mahmud.docx
# 167    Shiva G-Java Resume.docx
# 168    Siddhartha Gandroju.docx
# 169    Smita Kamble_Resume.docx
# 170    Sougandh_Java Fullstack Developer.docx
# 171    Spoorthi Finance BSA Resume.docx
# 172    Sr. Business Analyst.docx
# 173    Sravani Battu.docx
# 174    Sravani Singirikonda.docx
# 175    Sri Gati.docx
# 176    srinivas b.docx
# 177    Srivatsan_Project_Manager.docx
# 178    Sudhakar Reddy.docx
# 179    Sumanth Manne Java Developer.docx
# 180    Sundar_Java_8+ Years..docx
# 181    SUNITHA Project Manager (1).docx
# 182    Syed_Zia_Ashraf.docx
# 183    Tanmay_Dam_Resume_BA.docx
# 184    Tarun RESUME-BSAT.docx
# 185    Tarun Resume.docx
# 186    Tarun.docx
# 187    Tarun_Developer.docx
# 188    Tejaswi-resume.docx
# 189    Tushar Patel.docx
# 190    Uday_Maripelly.docx
# 191    Ujvala BA Feb 20.docx
# 192    Utthan Silawal12.docx
# 193    V Ashok A.docx
# 194    Vamshi L.docx
# 195    Vamshi Teja_Business Analyst.docx
# 196    Varun Kumar.docx
# 197    Varun.docx
# 198    vema reddy.docx
# 199    Venkata_Sr.PHP_Developer.docx
# 200    Venkat_BA.docx
# 201    venu b.docx
# 202    Vijay Bhargav.docx
# 203    VIJETHA G.docx
# 204    vikas java.docx
# 205    Vikash_BA_Ab.docx
# 206    Vinay.D_Resume.docx
# 207    Vishal S..docx
# 208    Vishnu BA Resume.docx
# 209    Vishnu J.docx
# 210    Vivek Joshi_CV.docx
# 211    Vivek.BSA.docx
# 212    Yohan BSA.docx
# 213    Yugesh_Resume.docx
#                                    cv_score  tf_idf_score  bert_score
# candidate_name
# Abiral_Pandey_Fullstack_Java.docx     14.04          8.52       71.33
# Achyuth Resume_8.docx                 14.91          9.06       65.64
# Adelina_Erimia_PMP1.docx              39.16         29.85       62.39
# Adhi Gopalam - SM.docx                46.38         36.92       60.85
# AjayKumar.docx                        47.05         38.24       64.17
# ...                                     ...           ...         ...
# Vishnu J.docx                         15.21          9.54       72.42
# Vivek Joshi_CV.docx                   41.60         29.29       78.97
# Vivek.BSA.docx                        42.90         30.80       72.47
# Yohan BSA.docx                        41.28         29.71       81.02
# Yugesh_Resume.docx                    16.21         10.24       63.42
#
# [214 rows x 3 columns]
